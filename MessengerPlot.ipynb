# %% [markdown]
# <a href="https://colab.research.google.com/github/meloly4/NLP-Projects/blob/master/MessengerPlot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import json
import nltk
from nltk.corpus import stopwords 
nltk.download('stopwords')
from nltk.tokenize import sent_tokenize, word_tokenize
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from matplotlib import rcParams
% matplotlib inline
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
sw = set(stopwords.words('english')) 
mess = []
with open('/content/drive/My Drive/fb messenger/message_1.json', 'r') as f:
  data = json.load(f)
  for item in (data.get('messages')):
    mess.append(str(item.get('content')))

me = " ".join(mess).lower()
wordcloud = WordCloud(stopwords=sw, background_color="white", max_words=1000).generate(me)
rcParams['figure.figsize'] = 25,50
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
